# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('./data/data_akbilgic.xlsx', skiprows=1)
df.head()
# Out:
# /Users/cheolj/Desktop/coder/pytorch/venv/lib/python3.8/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#         date       ISE     ISE.1        SP       DAX      FTSE    NIKKEI
# 0 2009-01-05  0.035754  0.038376 -0.004679  0.002193  0.003894  0.000000  \
# 1 2009-01-06  0.025426  0.031813  0.007787  0.008455  0.012866  0.004162
# 2 2009-01-07 -0.028862 -0.026353 -0.030469 -0.017833 -0.028735  0.017293
# 3 2009-01-08 -0.062208 -0.084716  0.003391 -0.011726 -0.000466 -0.040061
# 4 2009-01-09  0.009860  0.009658 -0.021533 -0.019873 -0.012710 -0.004474
#
#     BOVESPA        EU        EM
# 0  0.031190  0.012698  0.028524
# 1  0.018920  0.011341  0.008773
# 2 -0.035899 -0.017073 -0.020015
# 3  0.028283 -0.005561 -0.019424
# 4 -0.009764 -0.010989 -0.007802

# %%
df.datae = pd.to_datetime(df.date, yearfirst=True)
# Out:
# /var/folders/25/674ngcfx7sbgn8r3q8sy96840000gp/T/ipykernel_3680/2266497435.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.datae = pd.to_datetime(df.date, yearfirst=True)

# %%
df.date.min(), df.date.max()
# Out:
# (Timestamp('2009-01-05 00:00:00'), Timestamp('2011-02-22 00:00:00'))

# %%
block_data = pd.read_csv('./data/acorn/hhblock_dataset/hhblock_dataset/block_0.csv')
block_data.head()
# Out:
#        LCLid         day   hh_0   hh_1   hh_2   hh_3   hh_4   hh_5   hh_6
# 0  MAC000002  2012-10-13  0.263  0.269  0.275  0.256  0.211  0.136  0.161  \
# 1  MAC000002  2012-10-14  0.262  0.166  0.226  0.088  0.126  0.082  0.123
# 2  MAC000002  2012-10-15  0.192  0.097  0.141  0.083  0.132  0.070  0.130
# 3  MAC000002  2012-10-16  0.237  0.237  0.193  0.118  0.098  0.107  0.094
# 4  MAC000002  2012-10-17  0.157  0.211  0.155  0.169  0.101  0.117  0.084
#
#     hh_7  ...  hh_38  hh_39  hh_40  hh_41  hh_42  hh_43  hh_44  hh_45  hh_46
# 0  0.119  ...  0.918  0.278  0.267  0.239  0.230  0.233  0.235  0.188  0.259  \
# 1  0.083  ...  1.075  0.956  0.821  0.745  0.712  0.511  0.231  0.210  0.278
# 2  0.074  ...  1.164  0.249  0.225  0.258  0.260  0.334  0.299  0.236  0.241
# 3  0.109  ...  0.966  0.172  0.192  0.228  0.203  0.211  0.188  0.213  0.157
# 4  0.118  ...  0.223  0.075  0.230  0.208  0.265  0.377  0.327  0.277  0.288
#
#    hh_47
# 0  0.250
# 1  0.159
# 2  0.237
# 3  0.202
# ...

# %%
hh_data = pd.read_csv('./data/acorn/halfhourly_dataset/halfhourly_dataset/block_0.csv')
hh_data.head()
# Out:
#        LCLid                         tstp energy(kWh/hh)
# 0  MAC000002  2012-10-12 00:30:00.0000000             0
# 1  MAC000002  2012-10-12 01:00:00.0000000             0
# 2  MAC000002  2012-10-12 01:30:00.0000000             0
# 3  MAC000002  2012-10-12 02:00:00.0000000             0
# 4  MAC000002  2012-10-12 02:30:00.0000000             0

# %%
daily_data = pd.read_csv('./data/acorn/daily_dataset/daily_dataset/block_0.csv')
daily_data.head()
# Out:
#        LCLid         day  energy_median  energy_mean  energy_max
# 0  MAC000002  2012-10-12         0.1385     0.154304       0.886  \
# 1  MAC000002  2012-10-13         0.1800     0.230979       0.933
# 2  MAC000002  2012-10-14         0.1580     0.275479       1.085
# 3  MAC000002  2012-10-15         0.1310     0.213688       1.164
# 4  MAC000002  2012-10-16         0.1450     0.203521       0.991
#
#    energy_count  energy_std  energy_sum  energy_min
# 0            46    0.196034       7.098       0.000
# 1            48    0.192329      11.087       0.076
# 2            48    0.274647      13.223       0.070
# 3            48    0.224483      10.257       0.070
# 4            48    0.184115       9.769       0.087
